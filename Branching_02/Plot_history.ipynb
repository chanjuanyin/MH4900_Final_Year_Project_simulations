# %% [markdown]
# # Plot history
#
# In this file, we are going to plot the results of our simulation.
#
# We will perform the following actions:
# * Plot the real values of the PDE function
# * Plot the estimated PDE values generated using Monte Carlo simulation
#
# Please run the following codes:

# %% [markdown]
# ## Table of Content
#
# - [1 - Packages](#1)
# - [2 - Plotting the results of our simulation](#2)
#     - [2.1 - Load the relevant csv files](#2-1)
#     - [2.2 - Plot the PDE in one dimension: fix x in {2, 3, ..., 10} and varies t within [0, x-1]](#2-2)

# %% [markdown]
# <a name='1'></a>
# ## 1 - Packages
#
# Run the cell below to import all the libraries you'll need:

# %%
# From system
import os
import shutil
from pathlib import Path
import random

# Data structure
import numpy as np
import pandas as pd
import json
import csv

# Image processing
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# <a name='2'></a>
# ## 2 - Plotting the results of our simulation

# %% [markdown]
# <a name='2-1'></a>
# ### 2.1 - Load the relevant csv files

# %%
np_dictionary = {}

dir_name = "output"
os_listdir = os.listdir(dir_name)
for file_name in os_listdir:
    file_path = os.path.join(dir_name, file_name)
    data =  pd.read_csv(file_path, delimiter=',', dtype=None, header=None)
    np_dictionary[file_name[:-4]] = data

# %% [markdown]
# <a name='2-3'></a>
# ### 2.2 - Plot the PDE in one dimension: fix x in {2, 3, ..., 10} and varies t within [0, x-1]

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np.asarray(np_dictionary["n_equals_3_x_equals_2"])
real_values = np.reshape(real_values, (1001,))[0:101]
t_values = np.arange(0, 1.01, 0.01)
estimated_values = np.asarray(np_dictionary["n_equals_3_x_equals_2_monte_carlo"])
estimated_values = np.reshape(estimated_values, (11,))
t_estimated = np.arange(0, 1.1, 0.1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values of u(t,2)')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

# initial_condition_real_values = np.asarray(np_dictionary["x_equals_0"])
# initial_condition_real_values = np.reshape(initial_condition_real_values, (901,))
# t_values_initial = np.arange(1, 10.01, 0.01)
# plt.plot(t_values_initial, initial_condition_real_values, label='Initial condition u(t,0)')

plt.ylabel('real vs estimated values')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of u(t,2)')
plt.legend(loc='upper right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np.asarray(np_dictionary["n_equals_3_x_equals_3"])
real_values = np.reshape(real_values, (1001,))[0:201]
t_values = np.arange(0, 2.01, 0.01)
estimated_values = np.asarray(np_dictionary["n_equals_3_x_equals_3_monte_carlo"])
estimated_values = np.reshape(estimated_values, (21,))
t_estimated = np.arange(0, 2.1, 0.1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values of u(t,3)')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

# initial_condition_real_values = np.asarray(np_dictionary["x_equals_0"])
# initial_condition_real_values = np.reshape(initial_condition_real_values, (901,))
# t_values_initial = np.arange(1, 10.01, 0.01)
# plt.plot(t_values_initial, initial_condition_real_values, label='Initial condition u(t,0)')

plt.ylabel('real vs estimated values')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of u(t,3)')
plt.legend(loc='upper right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np.asarray(np_dictionary["n_equals_3_x_equals_4"])
real_values = np.reshape(real_values, (1001,))[0:301]
t_values = np.arange(0, 3.01, 0.01)
estimated_values = np.asarray(np_dictionary["n_equals_3_x_equals_4_monte_carlo"])
estimated_values = np.reshape(estimated_values, (31,))
t_estimated = np.arange(0, 3.1, 0.1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values of u(t,4)')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

# initial_condition_real_values = np.asarray(np_dictionary["x_equals_0"])
# initial_condition_real_values = np.reshape(initial_condition_real_values, (901,))
# t_values_initial = np.arange(1, 10.01, 0.01)
# plt.plot(t_values_initial, initial_condition_real_values, label='Initial condition u(t,0)')

plt.ylabel('real vs estimated values')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of u(t,4)')
plt.legend(loc='upper right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np.asarray(np_dictionary["n_equals_3_x_equals_5"])
real_values = np.reshape(real_values, (1001,))[0:401]
t_values = np.arange(0, 4.01, 0.01)
estimated_values = np.asarray(np_dictionary["n_equals_3_x_equals_5_monte_carlo"])
estimated_values = np.reshape(estimated_values, (41,))
t_estimated = np.arange(0, 4.1, 0.1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values of u(t,5)')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

# initial_condition_real_values = np.asarray(np_dictionary["x_equals_0"])
# initial_condition_real_values = np.reshape(initial_condition_real_values, (901,))
# t_values_initial = np.arange(1, 10.01, 0.01)
# plt.plot(t_values_initial, initial_condition_real_values, label='Initial condition u(t,0)')

plt.ylabel('real vs estimated values')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of u(t,5)')
plt.legend(loc='upper right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np.asarray(np_dictionary["n_equals_3_x_equals_6"])
real_values = np.reshape(real_values, (1001,))[0:501]
t_values = np.arange(0, 5.01, 0.01)
estimated_values = np.asarray(np_dictionary["n_equals_3_x_equals_6_monte_carlo"])
estimated_values = np.reshape(estimated_values, (51,))[0:31]
t_estimated = np.arange(0, 3.1, 0.1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values of u(t,6)')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

# initial_condition_real_values = np.asarray(np_dictionary["x_equals_0"])
# initial_condition_real_values = np.reshape(initial_condition_real_values, (901,))
# t_values_initial = np.arange(1, 10.01, 0.01)
# plt.plot(t_values_initial, initial_condition_real_values, label='Initial condition u(t,0)')

plt.ylabel('real vs estimated values')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of u(t,6)')
plt.legend(loc='upper right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np.asarray(np_dictionary["n_equals_3_x_equals_7"])
real_values = np.reshape(real_values, (1001,))[0:601]
t_values = np.arange(0, 6.01, 0.01)
estimated_values = np.asarray(np_dictionary["n_equals_3_x_equals_7_monte_carlo"])
estimated_values = np.reshape(estimated_values, (61,))[0:51]
t_estimated = np.arange(0, 5.1, 0.1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values of u(t,7)')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

# initial_condition_real_values = np.asarray(np_dictionary["x_equals_0"])
# initial_condition_real_values = np.reshape(initial_condition_real_values, (901,))
# t_values_initial = np.arange(1, 10.01, 0.01)
# plt.plot(t_values_initial, initial_condition_real_values, label='Initial condition u(t,0)')

plt.ylabel('real vs estimated values')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of u(t,7)')
plt.legend(loc='upper right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np.asarray(np_dictionary["n_equals_3_x_equals_8"])
real_values = np.reshape(real_values, (1001,))[0:701]
t_values = np.arange(0, 7.01, 0.01)
estimated_values = np.asarray(np_dictionary["n_equals_3_x_equals_8_monte_carlo"])
estimated_values = np.reshape(estimated_values, (71,))[0:51]
t_estimated = np.arange(0, 5.1, 0.1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values of u(t,8)')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

# initial_condition_real_values = np.asarray(np_dictionary["x_equals_0"])
# initial_condition_real_values = np.reshape(initial_condition_real_values, (901,))
# t_values_initial = np.arange(1, 10.01, 0.01)
# plt.plot(t_values_initial, initial_condition_real_values, label='Initial condition u(t,0)')

plt.ylabel('real vs estimated values')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of u(t,8)')
plt.legend(loc='upper right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np.asarray(np_dictionary["n_equals_3_x_equals_9"])
real_values = np.reshape(real_values, (1001,))[0:801]
t_values = np.arange(0, 8.01, 0.01)
estimated_values = np.asarray(np_dictionary["n_equals_3_x_equals_9_monte_carlo"])
estimated_values = np.reshape(estimated_values, (81,))[0:61]
t_estimated = np.arange(0, 6.1, 0.1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values of u(t,9)')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

# initial_condition_real_values = np.asarray(np_dictionary["x_equals_0"])
# initial_condition_real_values = np.reshape(initial_condition_real_values, (901,))
# t_values_initial = np.arange(1, 10.01, 0.01)
# plt.plot(t_values_initial, initial_condition_real_values, label='Initial condition u(t,0)')

plt.ylabel('real vs estimated values')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of u(t,9)')
plt.legend(loc='upper right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np.asarray(np_dictionary["n_equals_3_x_equals_10"])
real_values = np.reshape(real_values, (1001,))[0:901]
t_values = np.arange(0, 9.01, 0.01)
estimated_values = np.asarray(np_dictionary["n_equals_3_x_equals_10_monte_carlo"])
estimated_values = np.reshape(estimated_values, (91,))[0:61]
t_estimated = np.arange(0, 6.1, 0.1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values of u(t,10)')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

# initial_condition_real_values = np.asarray(np_dictionary["x_equals_0"])
# initial_condition_real_values = np.reshape(initial_condition_real_values, (901,))
# t_values_initial = np.arange(1, 10.01, 0.01)
# plt.plot(t_values_initial, initial_condition_real_values, label='Initial condition u(t,0)')

plt.ylabel('real vs estimated values')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of u(t,10)')
plt.legend(loc='upper right')
plt.show()
