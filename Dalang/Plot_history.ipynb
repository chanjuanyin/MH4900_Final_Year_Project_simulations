# %% [markdown]
# # Plot history
#
# In this file, we are going to plot the results of our simulation.
#
# We will perform the following actions:
# * Plot the real values of the PDE function
# * Plot the estimated PDE values generated using Monte Carlo simulation
#
# Please run the following codes:

# %% [markdown]
# ## Table of Content
#
# - [1 - Packages](#1)
# - [2 - Plotting the results of our simulation](#2)
#     - [2.1 - Load the relevant csv files](#2-1)
#     - [2.2 - Plot the PDE in one dimension: fix t in {0, 1, 2, ..., 10} and varies x within [-5, 5]](#2-2)
#     - [2.3 - Plot the PDE in one dimension: fix x in {-5, -4, ..., 4, 5} and varies t within [0, 10]](#2-3)

# %% [markdown]
# <a name='1'></a>
# ## 1 - Packages
#
# Run the cell below to import all the libraries you'll need:

# %%
# From system
import os
import shutil
from pathlib import Path
import random

# Data structure
import numpy as np
import pandas as pd
import json
import csv

# Image processing
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# <a name='2'></a>
# ## 2 - Plotting the results of our simulation

# %% [markdown]
# <a name='2-1'></a>
# ### 2.1 - Load the relevant csv files

# %%
np_dictionary = {}

dir_name = "output"
os_listdir = os.listdir(dir_name)
for file_name in os_listdir:
    file_path = os.path.join(dir_name, file_name)
    data = np.genfromtxt(file_path, delimiter=',', dtype=None)
    np_dictionary[file_name[:-4]] = data

# %% [markdown]
# <a name='2-2'></a>
# ### 2.2 - Plot the PDE in one dimension: fix t in {0, 1, 2, ..., 10} and varies x within [-5, 5]

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["t_equals_0"]
x_values = np.arange(-5, 5.01, 0.01)
estimated_values = np_dictionary["estimated_values"][:, 0]
x_estimated = np.arange(-5, 6, 1)

plt.figure(figsize=(12, 8))
plt.plot(x_values, real_values, label='Real values')
plt.plot(x_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(x,0)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('x values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(x,0)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["t_equals_1"]
x_values = np.arange(-5, 5.01, 0.01)
estimated_values = np_dictionary["estimated_values"][:, 1]
x_estimated = np.arange(-5, 6, 1)

plt.figure(figsize=(12, 8))
plt.plot(x_values, real_values, label='Real values')
plt.plot(x_estimated, estimated_values, 'ro-', label='Estimated values')

initial_condition_real_values = np_dictionary["t_equals_0"]
plt.plot(x_values, initial_condition_real_values, label='Initial condition F(x,0)')

plt.ylabel('F(x,1)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('x values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(x,1)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["t_equals_2"]
x_values = np.arange(-5, 5.01, 0.01)
estimated_values = np_dictionary["estimated_values"][:, 2]
x_estimated = np.arange(-5, 6, 1)

plt.figure(figsize=(12, 8))
plt.plot(x_values, real_values, label='Real values')
plt.plot(x_estimated, estimated_values, 'ro-', label='Estimated values')

initial_condition_real_values = np_dictionary["t_equals_0"]
plt.plot(x_values, initial_condition_real_values, label='Initial condition F(x,0)')

plt.ylabel('F(x,2)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('x values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(x,2)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["t_equals_3"]
x_values = np.arange(-5, 5.01, 0.01)
estimated_values = np_dictionary["estimated_values"][:, 3]
x_estimated = np.arange(-5, 6, 1)

plt.figure(figsize=(12, 8))
plt.plot(x_values, real_values, label='Real values')
plt.plot(x_estimated, estimated_values, 'ro-', label='Estimated values')

initial_condition_real_values = np_dictionary["t_equals_0"]
plt.plot(x_values, initial_condition_real_values, label='Initial condition F(x,0)')

plt.ylabel('F(x,3)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('x values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(x,3)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["t_equals_4"]
x_values = np.arange(-5, 5.01, 0.01)
estimated_values = np_dictionary["estimated_values"][:, 4]
x_estimated = np.arange(-5, 6, 1)

plt.figure(figsize=(12, 8))
plt.plot(x_values, real_values, label='Real values')
plt.plot(x_estimated, estimated_values, 'ro-', label='Estimated values')

initial_condition_real_values = np_dictionary["t_equals_0"]
plt.plot(x_values, initial_condition_real_values, label='Initial condition F(x,0)')

plt.ylabel('F(x,4)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('x values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(x,4)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["t_equals_5"]
x_values = np.arange(-5, 5.01, 0.01)
estimated_values = np_dictionary["estimated_values"][:, 5]
x_estimated = np.arange(-5, 6, 1)

plt.figure(figsize=(12, 8))
plt.plot(x_values, real_values, label='Real values')
plt.plot(x_estimated, estimated_values, 'ro-', label='Estimated values')

initial_condition_real_values = np_dictionary["t_equals_0"]
plt.plot(x_values, initial_condition_real_values, label='Initial condition F(x,0)')

plt.ylabel('F(x,5)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('x values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(x,5)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["t_equals_6"]
x_values = np.arange(-5, 5.01, 0.01)
estimated_values = np_dictionary["estimated_values"][:, 6]
x_estimated = np.arange(-5, 6, 1)

plt.figure(figsize=(12, 8))
plt.plot(x_values, real_values, label='Real values')
plt.plot(x_estimated, estimated_values, 'ro-', label='Estimated values')

initial_condition_real_values = np_dictionary["t_equals_0"]
plt.plot(x_values, initial_condition_real_values, label='Initial condition F(x,0)')

plt.ylabel('F(x,6)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('x values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(x,6)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["t_equals_7"]
x_values = np.arange(-5, 5.01, 0.01)
estimated_values = np_dictionary["estimated_values"][:, 7]
x_estimated = np.arange(-5, 6, 1)

plt.figure(figsize=(12, 8))
plt.plot(x_values, real_values, label='Real values')
plt.plot(x_estimated, estimated_values, 'ro-', label='Estimated values')

initial_condition_real_values = np_dictionary["t_equals_0"]
plt.plot(x_values, initial_condition_real_values, label='Initial condition F(x,0)')

plt.ylabel('F(x,7)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('x values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(x,7)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["t_equals_8"]
x_values = np.arange(-5, 5.01, 0.01)
estimated_values = np_dictionary["estimated_values"][:, 8]
x_estimated = np.arange(-5, 6, 1)

plt.figure(figsize=(12, 8))
plt.plot(x_values, real_values, label='Real values')
plt.plot(x_estimated, estimated_values, 'ro-', label='Estimated values')

initial_condition_real_values = np_dictionary["t_equals_0"]
plt.plot(x_values, initial_condition_real_values, label='Initial condition F(x,0)')

plt.ylabel('F(x,8)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('x values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(x,8)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["t_equals_9"]
x_values = np.arange(-5, 5.01, 0.01)
estimated_values = np_dictionary["estimated_values"][:, 9]
x_estimated = np.arange(-5, 6, 1)

plt.figure(figsize=(12, 8))
plt.plot(x_values, real_values, label='Real values')
plt.plot(x_estimated, estimated_values, 'ro-', label='Estimated values')

initial_condition_real_values = np_dictionary["t_equals_0"]
plt.plot(x_values, initial_condition_real_values, label='Initial condition F(x,0)')

plt.ylabel('F(x,9)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('x values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(x,9)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["t_equals_10"]
x_values = np.arange(-5, 5.01, 0.01)
estimated_values = np_dictionary["estimated_values"][:, 10]
x_estimated = np.arange(-5, 6, 1)

plt.figure(figsize=(12, 8))
plt.plot(x_values, real_values, label='Real values')
plt.plot(x_estimated, estimated_values, 'ro-', label='Estimated values')

initial_condition_real_values = np_dictionary["t_equals_0"]
plt.plot(x_values, initial_condition_real_values, label='Initial condition F(x,0)')

plt.ylabel('F(x,10)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('x values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(x,10)')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# <a name='2-3'></a>
# ### 2.3 - Plot the PDE in one dimension: fix x in {-5, -4, ..., 4, 5} and varies t within [0, 10]

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["x_equals_neg_5"]
t_values = np.arange(0, 10.01, 0.01)
estimated_values = np_dictionary["estimated_values"][0, :]
t_estimated = np.arange(0, 11, 1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(-5,t)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(-5,t)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["x_equals_neg_4"]
t_values = np.arange(0, 10.01, 0.01)
estimated_values = np_dictionary["estimated_values"][1, :]
t_estimated = np.arange(0, 11, 1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(-4,t)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(-4,t)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["x_equals_neg_3"]
t_values = np.arange(0, 10.01, 0.01)
estimated_values = np_dictionary["estimated_values"][2, :]
t_estimated = np.arange(0, 11, 1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(-3,t)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(-3,t)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["x_equals_neg_2"]
t_values = np.arange(0, 10.01, 0.01)
estimated_values = np_dictionary["estimated_values"][3, :]
t_estimated = np.arange(0, 11, 1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(-2,t)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(-2,t)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["x_equals_neg_1"]
t_values = np.arange(0, 10.01, 0.01)
estimated_values = np_dictionary["estimated_values"][4, :]
t_estimated = np.arange(0, 11, 1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(-1,t)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(-1,t)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["x_equals_0"]
t_values = np.arange(0, 10.01, 0.01)
estimated_values = np_dictionary["estimated_values"][5, :]
t_estimated = np.arange(0, 11, 1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(0,t)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(0,t)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["x_equals_pos_1"]
t_values = np.arange(0, 10.01, 0.01)
estimated_values = np_dictionary["estimated_values"][6, :]
t_estimated = np.arange(0, 11, 1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(1,t)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(1,t)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["x_equals_pos_2"]
t_values = np.arange(0, 10.01, 0.01)
estimated_values = np_dictionary["estimated_values"][7, :]
t_estimated = np.arange(0, 11, 1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(2,t)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(2,t)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["x_equals_pos_3"]
t_values = np.arange(0, 10.01, 0.01)
estimated_values = np_dictionary["estimated_values"][8, :]
t_estimated = np.arange(0, 11, 1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(3,t)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(3,t)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["x_equals_pos_4"]
t_values = np.arange(0, 10.01, 0.01)
estimated_values = np_dictionary["estimated_values"][9, :]
t_estimated = np.arange(0, 11, 1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(4,t)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(4,t)')
plt.legend(loc='lower right')
plt.show()

# %%
impose_ylim = False
y_lim = [0,0.2]

real_values = np_dictionary["x_equals_pos_5"]
t_values = np.arange(0, 10.01, 0.01)
estimated_values = np_dictionary["estimated_values"][10, :]
t_estimated = np.arange(0, 11, 1)

plt.figure(figsize=(12, 8))
plt.plot(t_values, real_values, label='Real values')
plt.plot(t_estimated, estimated_values, 'ro-', label='Estimated values')

plt.ylabel('F(5,t)')
if impose_ylim:
    plt.ylim(y_lim)
plt.xlabel('t values')
# plt.axvline(x=30,color='red')

plt.title('Real vs estimated values of F(5,t)')
plt.legend(loc='lower right')
plt.show()
